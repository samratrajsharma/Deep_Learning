# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from tensorflow.keras.layers import Activation, Dense, Input
from tensorflow.keras.layers import Conv2D, Flatten
from tensorflow.keras.layers import Reshape, Conv2DTranspose
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.optimizers import legacy  # Import legacy optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import load_model

import numpy as np
import math
import matplotlib.pyplot as plt
import os
import argparse


def build_generator(inputs, image_size):
    image_resize = image_size // 4
    kernel_size = 5
    layer_filters = [128, 64, 32, 1]

    x = Dense(image_resize * image_resize * layer_filters[0])(inputs)
    x = Reshape((image_resize, image_resize, layer_filters[0]))(x)

    for filters in layer_filters:
        if filters > layer_filters[-2]:
            strides = 2
        else:
            strides = 1
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Conv2DTranspose(filters=filters,
                            kernel_size=kernel_size,
                            strides=strides,
                            padding='same')(x)

    x = Activation('sigmoid')(x)
    generator = Model(inputs, x, name='generator')
    return generator


def build_discriminator(inputs):
    kernel_size = 5
    layer_filters = [32, 64, 128, 256]

    x = inputs
    for filters in layer_filters:
        if filters == layer_filters[-1]:
            strides = 1
        else:
            strides = 2
        x = LeakyReLU(alpha=0.2)(x)
        x = Conv2D(filters=filters,
                   kernel_size=kernel_size,
                   strides=strides,
                   padding='same')(x)

    x = Flatten()(x)
    x = Dense(1)(x)
    x = Activation('sigmoid')(x)
    discriminator = Model(inputs, x, name='discriminator')
    return discriminator


def train(models, x_train, params):
    generator, discriminator, adversarial = models
    batch_size, latent_size, train_steps, model_name = params
    save_interval = 500
    noise_input = np.random.uniform(-1.0, 1.0, size=[16, latent_size])
    train_size = x_train.shape[0]
    for i in range(train_steps):
        rand_indexes = np.random.randint(0, train_size, size=batch_size)
        real_images = x_train[rand_indexes]
        noise = np.random.uniform(-1.0, 1.0, size=[batch_size, latent_size])
        fake_images = generator.predict(noise)
        x = np.concatenate((real_images, fake_images))
        y = np.ones([2 * batch_size, 1])
        y[batch_size:, :] = 0.0
        loss, acc = discriminator.train_on_batch(x, y)
        log = "%d: [discriminator loss: %f, acc: %f]" % (i, loss, acc)

        noise = np.random.uniform(-1.0, 1.0, size=[batch_size, latent_size])
        y = np.ones([batch_size, 1])
        loss, acc = adversarial.train_on_batch(noise, y)
        log = "%s [adversarial loss: %f, acc: %f]" % (log, loss, acc)
        print(log)
        if (i + 1) % save_interval == 0:
            plot_images(generator,
                        noise_input=noise_input,
                        show=False,
                        step=(i + 1),
                        model_name=model_name)

    generator.save(model_name + ".h5")


def plot_images(generator,
                noise_input,
                show=False,
                step=0,
                model_name="gan"):
    os.makedirs(model_name, exist_ok=True)
    filename = os.path.join(model_name, "%05d.png" % step)
    images = generator.predict(noise_input)
    plt.figure(figsize=(2.2, 2.2))
    num_images = images.shape[0]
    image_size = images.shape[1]
    rows = int(math.sqrt(noise_input.shape[0]))
    for i in range(num_images):
        plt.subplot(rows, rows, i + 1)
        image = np.reshape(images[i], [image_size, image_size])
        plt.imshow(image, cmap='gray')
        plt.axis('off')
    plt.savefig(filename)
    if show:
        plt.show()
    else:
        plt.close('all')


def build_and_train_models():
    (x_train, _), (_, _) = mnist.load_data()

    image_size = x_train.shape[1]
    x_train = np.reshape(x_train, [-1, image_size, image_size, 1])
    x_train = x_train.astype('float32') / 255

    model_name = "dcgan_mnist"
    latent_size = 100
    batch_size = 64
    train_steps = 400
    lr = 2e-4
    decay = 6e-8
    input_shape = (image_size, image_size, 1)

    inputs = Input(shape=input_shape, name='discriminator_input')
    discriminator = build_discriminator(inputs)
    optimizer = legacy.RMSprop(learning_rate=lr, decay=decay)  # Use legacy RMSprop optimizer
    discriminator.compile(loss='binary_crossentropy',
                          optimizer=optimizer,
                          metrics=['accuracy'])
    discriminator.summary()

    input_shape = (latent_size, )
    inputs = Input(shape=input_shape, name='z_input')
    generator = build_generator(inputs, image_size)
    generator.summary()

    optimizer = legacy.RMSprop(learning_rate=lr * 0.5, decay=decay * 0.5)  # Use legacy RMSprop optimizer
    discriminator.trainable = False
    adversarial = Model(inputs, 
                        discriminator(generator(inputs)),
                        name=model_name)
    adversarial.compile(loss='binary_crossentropy',
                        optimizer=optimizer,
                        metrics=['accuracy'])
    adversarial.summary()

    models = (generator, discriminator, adversarial)
    params = (batch_size, latent_size, train_steps, model_name)
    train(models, x_train, params)


def test_generator(generator):
    noise_input = np.random.uniform(-1.0, 1.0, size=[16, 100])
    plot_images(generator,
                noise_input=noise_input,
                show=True,
                model_name="test_outputs")


if __name__ == '__main__':
    build_and_train_models()
# Out:
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  discriminator_input (Input  [(None, 28, 28, 1)]       0
#  Layer)
#
#  leaky_re_lu_24 (LeakyReLU)  (None, 28, 28, 1)         0
#
#  conv2d_24 (Conv2D)          (None, 14, 14, 32)        832
#
#  leaky_re_lu_25 (LeakyReLU)  (None, 14, 14, 32)        0
#
#  conv2d_25 (Conv2D)          (None, 7, 7, 64)          51264
#
#  leaky_re_lu_26 (LeakyReLU)  (None, 7, 7, 64)          0
#
#  conv2d_26 (Conv2D)          (None, 4, 4, 128)         204928
#
#  leaky_re_lu_27 (LeakyReLU)  (None, 4, 4, 128)         0
#
#  conv2d_27 (Conv2D)          (None, 4, 4, 256)         819456
#
#  flatten_6 (Flatten)         (None, 4096)              0
#
#  dense_7 (Dense)             (None, 1)                 4097
#
#  activation_11 (Activation)  (None, 1)                 0
#
# =================================================================
# Total params: 1080577 (4.12 MB)
# Trainable params: 1080577 (4.12 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  z_input (InputLayer)        [(None, 100)]             0
#
#  dense_8 (Dense)             (None, 6272)              633472
#
#  reshape_1 (Reshape)         (None, 7, 7, 128)         0
#
#  batch_normalization_4 (Bat  (None, 7, 7, 128)         512
#  chNormalization)
#
#  activation_12 (Activation)  (None, 7, 7, 128)         0
#
#  conv2d_transpose_4 (Conv2D  (None, 14, 14, 128)       409728
#  Transpose)
#
#  batch_normalization_5 (Bat  (None, 14, 14, 128)       512
#  chNormalization)
#
#  activation_13 (Activation)  (None, 14, 14, 128)       0
#
#  conv2d_transpose_5 (Conv2D  (None, 28, 28, 64)        204864
#  Transpose)
#
#  batch_normalization_6 (Bat  (None, 28, 28, 64)        256
#  chNormalization)
#
#  activation_14 (Activation)  (None, 28, 28, 64)        0
#
#  conv2d_transpose_6 (Conv2D  (None, 28, 28, 32)        51232
#  Transpose)
#
#  batch_normalization_7 (Bat  (None, 28, 28, 32)        128
#  chNormalization)
#
#  activation_15 (Activation)  (None, 28, 28, 32)        0
#
#  conv2d_transpose_7 (Conv2D  (None, 28, 28, 1)         801
#  Transpose)
#
#  activation_16 (Activation)  (None, 28, 28, 1)         0
#
# =================================================================
# Total params: 1301505 (4.96 MB)
# Trainable params: 1300801 (4.96 MB)
# Non-trainable params: 704 (2.75 KB)
# _________________________________________________________________
# Model: "dcgan_mnist"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  z_input (InputLayer)        [(None, 100)]             0
#
#  generator (Functional)      (None, 28, 28, 1)         1301505
#
#  discriminator (Functional)  (None, 1)                 1080577
#
# =================================================================
# Total params: 2382082 (9.09 MB)
# Trainable params: 1300801 (4.96 MB)
# Non-trainable params: 1081281 (4.12 MB)
# _________________________________________________________________
# 2/2 [==============================] - 0s 32ms/step
# 0: [discriminator loss: 0.693496, acc: 0.273438] [adversarial loss: 1.044317, acc: 0.000000]
# 2/2 [==============================] - 0s 32ms/step
# 1: [discriminator loss: 0.580107, acc: 0.664062] [adversarial loss: 1.202076, acc: 0.000000]
# 2/2 [==============================] - 0s 32ms/step
# 2: [discriminator loss: 0.446451, acc: 0.945312] [adversarial loss: 1.066417, acc: 0.000000]
# 2/2 [==============================] - 0s 33ms/step
# 3: [discriminator loss: 0.280193, acc: 0.992188] [adversarial loss: 1.412110, acc: 0.000000]
# 2/2 [==============================] - 0s 23ms/step
# 4: [discriminator loss: 0.152925, acc: 0.992188] [adversarial loss: 0.269600, acc: 1.000000]
# 2/2 [==============================] - 0s 31ms/step
# 5: [discriminator loss: 0.176488, acc: 1.000000] [adversarial loss: 3.414303, acc: 0.000000]
# 2/2 [==============================] - 0s 30ms/step
# 6: [discriminator loss: 0.148336, acc: 0.960938] [adversarial loss: 1.376458, acc: 0.000000]
# 2/2 [==============================] - 0s 27ms/step
# 7: [discriminator loss: 0.056085, acc: 0.984375] [adversarial loss: 0.826023, acc: 0.000000]
# 2/2 [==============================] - 0s 27ms/step
# 8: [discriminator loss: 0.031214, acc: 1.000000] [adversarial loss: 0.677645, acc: 0.640625]
# 2/2 [==============================] - 0s 35ms/step
# 9: [discriminator loss: 0.036662, acc: 1.000000] [adversarial loss: 0.411485, acc: 1.000000]
# 2/2 [==============================] - 0s 45ms/step
# 10: [discriminator loss: 0.025878, acc: 1.000000] [adversarial loss: 0.322222, acc: 1.000000]
# 2/2 [==============================] - 0s 39ms/step
# 11: [discriminator loss: 0.027584, acc: 1.000000] [adversarial loss: 0.181110, acc: 1.000000]
# 2/2 [==============================] - 0s 38ms/step
# 12: [discriminator loss: 0.016973, acc: 1.000000] [adversarial loss: 0.176643, acc: 1.000000]
# 380: [discriminator loss: 0.073649, acc: 0.992188] [adversarial loss: 0.774128, acc: 0.171875]
# 2/2 [==============================] - 0s 39ms/step
# 381: [discriminator loss: 0.110413, acc: 0.976562] [adversarial loss: 0.333835, acc: 1.000000]
# 2/2 [==============================] - 0s 32ms/step
# 382: [discriminator loss: 0.079331, acc: 1.000000] [adversarial loss: 1.502642, acc: 0.000000]
# 2/2 [==============================] - 0s 35ms/step
# 383: [discriminator loss: 0.058772, acc: 1.000000] [adversarial loss: 0.593578, acc: 0.875000]
# 2/2 [==============================] - 0s 30ms/step
# 384: [discriminator loss: 0.069202, acc: 1.000000] [adversarial loss: 1.558195, acc: 0.000000]
# 2/2 [==============================] - 0s 34ms/step
# 385: [discriminator loss: 0.101484, acc: 0.992188] [adversarial loss: 0.721328, acc: 0.437500]
# 2/2 [==============================] - 0s 36ms/step
# 386: [discriminator loss: 0.281744, acc: 0.929688] [adversarial loss: 0.857218, acc: 0.078125]
# 2/2 [==============================] - 0s 34ms/step
# 387: [discriminator loss: 0.148079, acc: 0.976562] [adversarial loss: 0.009355, acc: 1.000000]
# 2/2 [==============================] - 0s 34ms/step
# 388: [discriminator loss: 0.282407, acc: 0.867188] [adversarial loss: 6.465028, acc: 0.000000]
# 2/2 [==============================] - 0s 35ms/step
# 389: [discriminator loss: 1.029034, acc: 0.640625] [adversarial loss: 0.000002, acc: 1.000000]
# 2/2 [==============================] - 0s 36ms/step
# 390: [discriminator loss: 0.832543, acc: 0.546875] [adversarial loss: 0.007295, acc: 1.000000]
# 2/2 [==============================] - 0s 35ms/step
# 391: [discriminator loss: 0.100075, acc: 1.000000] [adversarial loss: 0.041696, acc: 1.000000]
# 2/2 [==============================] - 0s 43ms/step
# 392: [discriminator loss: 0.085945, acc: 1.000000] [adversarial loss: 0.139681, acc: 1.000000]
# 2/2 [==============================] - 0s 33ms/step
# 393: [discriminator loss: 0.072176, acc: 0.992188] [adversarial loss: 0.315389, acc: 1.000000]
# 2/2 [==============================] - 0s 33ms/step
# 394: [discriminator loss: 0.090954, acc: 0.992188] [adversarial loss: 0.318998, acc: 1.000000]
# 2/2 [==============================] - 0s 35ms/step
# 395: [discriminator loss: 0.070472, acc: 1.000000] [adversarial loss: 0.745328, acc: 0.375000]
# 2/2 [==============================] - 0s 36ms/step
# 396: [discriminator loss: 0.104926, acc: 0.968750] [adversarial loss: 0.264434, acc: 1.000000]
# 2/2 [==============================] - 0s 33ms/step
# 397: [discriminator loss: 0.127462, acc: 0.984375] [adversarial loss: 1.798381, acc: 0.000000]
# 2/2 [==============================] - 0s 34ms/step
# 398: [discriminator loss: 0.086142, acc: 0.992188] [adversarial loss: 0.232357, acc: 1.000000]
# 2/2 [==============================] - 0s 40ms/step
# 399: [discriminator loss: 0.131887, acc: 1.000000] [adversarial loss: 3.688352, acc: 0.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# C:\Users\prave\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 22
#      19     plt.show()
#      21 # Tumhara trained generator yahan use karo
# ---> 22 plot_generated_images(generator_model=generator)
#
# NameError: name 'generator' is not defined
